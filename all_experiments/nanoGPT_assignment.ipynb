# %%
# ====== 1. Environment prep ======
# !git clone https://github.com/karpathy/nanoGPT.git
# %cd nanoGPT

# !pip install torch numpy transformers datasets tiktoken wandb tqdm psutil

import os
import itertools
import json
import psutil
import torch

# We'll make a directory to hold all experiment outputs/checkpoints
os.makedirs("all_experiments", exist_ok=True)
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 686, done.
# remote: Total 686 (delta 0), reused 0 (delta 0), pack-reused 686 (from 1)
# Receiving objects: 100% (686/686), 974.06 KiB | 32.47 MiB/s, done.
# Resolving deltas: 100% (380/380), done.
# /content/nanoGPT
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.11.10)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.42.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# ====== 2. Define the fixed + sweep hyperparams ======
FIXED = {
    "block_size": 128,
    "n_layer": 6,
}

SWEEP = {
    "n_head":       [4, 8],
    "n_embd":       [128, 256],
    "batch_size":   [8, 16],
    "max_iters":    [1000, 2000],
    "dropout":      [0.1, 0.2],
}

# cartesian product over SWEEP
keys = list(SWEEP.keys())
all_settings = []
for values in itertools.product(*[SWEEP[k] for k in keys]):
    cfg = {k:v for k,v in zip(keys, values)}
    cfg.update(FIXED)
    all_settings.append(cfg)

print(f"Total experiments: {len(all_settings)}")  # should be 32

# preview a few configs
for i, cfg in enumerate(all_settings[:3]):
    print(f"[exp {i}] {cfg}")
# Out:
# Total experiments: 32
# [exp 0] {'n_head': 4, 'n_embd': 128, 'batch_size': 8, 'max_iters': 1000, 'dropout': 0.1, 'block_size': 128, 'n_layer': 6}
# [exp 1] {'n_head': 4, 'n_embd': 128, 'batch_size': 8, 'max_iters': 1000, 'dropout': 0.2, 'block_size': 128, 'n_layer': 6}
# [exp 2] {'n_head': 4, 'n_embd': 128, 'batch_size': 8, 'max_iters': 2000, 'dropout': 0.1, 'block_size': 128, 'n_layer': 6}

# %%
# ====== 3. Helper: generate a unique run name + output dir per config ======
def make_run_id(cfg, idx):
    """
    Create a short, readable identifier for the run.
    We'll include only the swept params, since block_size and n_layer are fixed.
    """
    return (
        f"exp{idx:02d}"
        f"_head{cfg['n_head']}"
        f"_emb{cfg['n_embd']}"
        f"_bs{cfg['batch_size']}"
        f"_it{cfg['max_iters']}"
        f"_do{cfg['dropout']}"
    )

experiment_specs = []
for idx, cfg in enumerate(all_settings):
    run_id = make_run_id(cfg, idx)
    out_dir = os.path.join("all_experiments", run_id)
    os.makedirs(out_dir, exist_ok=True)
    spec = {
        "run_id": run_id,
        "out_dir": out_dir,
        **cfg
    }
    experiment_specs.append(spec)

print("Example spec:")
print(json.dumps(experiment_specs[0], indent=2))
# Out:
# Example spec:
# {
#   "run_id": "exp00_head4_emb128_bs8_it1000_do0.1",
#   "out_dir": "all_experiments/exp00_head4_emb128_bs8_it1000_do0.1",
#   "n_head": 4,
#   "n_embd": 128,
#   "batch_size": 8,
#   "max_iters": 1000,
#   "dropout": 0.1,
#   "block_size": 128,
#   "n_layer": 6
# }

# %%
# ====== 4. Helper: parameter count + memory usage snapshot ======
def model_size_report(n_layer, n_head, n_embd, block_size, vocab_size=50304):
    """
    We'll reuse the GPTConfig/GPT later to get exact param counts,
    but this gives you a quick estimate placeholder right now.
    We'll integrate exact numbers in the training loop step.
    """
    dummy = {
        "n_layer": n_layer,
        "n_head": n_head,
        "n_embd": n_embd,
        "block_size": block_size,
        "vocab_size": vocab_size,
    }
    return dummy

print("Memory info (host machine right now):")
print(psutil.virtual_memory())
print("GPU available:", torch.cuda.is_available())
# Out:
# Memory info (host machine right now):
# svmem(total=13605855232, available=12198588416, percent=10.3, used=1071562752, free=8133046272, active=525000704, inactive=4483432448, buffers=140955648, cached=4260290560, shared=2088960, slab=295710720)
# GPU available: True

# %%
import time
import math
import pickle
import psutil
import torch
import torch.nn.functional as F
from torch import nn
from contextlib import nullcontext

# import GPT model definition from nanoGPT repo
from model import GPT, GPTConfig

# We'll create a lightweight dataset loader similar to get_batch() in train.py
def build_data_loader(data_dir, block_size, batch_size, device_type, device):
    """
    Returns a callable get_batch(split) -> (X, Y)
    Expects data_dir/train.bin and data_dir/val.bin (uint16 token streams).
    """
    import numpy as np
    train_bin = os.path.join(data_dir, "train.bin")
    val_bin   = os.path.join(data_dir, "val.bin")

    def get_batch(split):
        data_path = train_bin if split == "train" else val_bin
        data = np.memmap(data_path, dtype=np.uint16, mode='r')
        ix = torch.randint(len(data) - block_size, (batch_size,))
        x = torch.stack([
            torch.from_numpy((data[i:i+block_size]).astype(np.int64))
            for i in ix
        ])
        y = torch.stack([
            torch.from_numpy((data[i+1:i+1+block_size]).astype(np.int64))
            for i in ix
        ])
        if device_type == "cuda":
            x, y = x.pin_memory().to(device, non_blocking=True), y.pin_memory().to(device, non_blocking=True)
        else:
            x, y = x.to(device), y.to(device)
        return x, y

    return get_batch

@torch.no_grad()
def estimate_loss(model, get_batch, eval_iters, ctx):
    """
    Compute mean train/val loss over eval_iters batches each.
    """
    model.eval()
    losses = {}
    for split in ["train", "val"]:
        split_losses = []
        for _ in range(eval_iters):
            X, Y = get_batch(split)
            with ctx:
                logits, loss = model(X, Y)
            split_losses.append(loss.item())
        losses[split] = sum(split_losses) / len(split_losses)
    model.train()
    return losses


def count_parameters(model):
    """
    Return total number of parameters that require grad.
    """
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def gpu_memory_allocated(device):
    if "cuda" in device:
        return torch.cuda.memory_allocated(device)
    return 0


def train_one_experiment(
    spec,
    data_dir="data/shakespeare_char",   # <-- you can change dataset here
    vocab_size_fallback=50304,
    eval_interval=200,                  # how often to eval & checkpoint
    eval_iters=20,                      # how many batches for eval avg
    log_interval=10,                    # how often to print/record iter stats
    weight_decay=1e-1,
    beta1=0.9,
    beta2=0.95,
    learning_rate=6e-4,
    warmup_iters=100,
    grad_clip=1.0,
    wandb_project="nano-sweep",
):

    """
    spec is one dict from experiment_specs we built in Part 1.
    Required keys:
      run_id, out_dir, n_head, n_embd, batch_size, max_iters,
      dropout, block_size, n_layer
    """

    run_id    = spec["run_id"]
    out_dir   = spec["out_dir"]
    n_head    = spec["n_head"]
    n_embd    = spec["n_embd"]
    batch_size= spec["batch_size"]
    max_iters = spec["max_iters"]
    dropout   = spec["dropout"]
    block_size= spec["block_size"]
    n_layer   = spec["n_layer"]

    # device / dtype setup (single GPU or CPU in Colab)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    device_type = "cuda" if "cuda" in device else "cpu"
    dtype = "bfloat16" if (device_type=="cuda" and torch.cuda.is_bf16_supported()) else "float16"
    ptdtype = {
        "float32": torch.float32,
        "bfloat16": torch.bfloat16,
        "float16": torch.float16,
    }[dtype]
    ctx = nullcontext() if device_type == "cpu" else torch.amp.autocast(device_type=device_type, dtype=ptdtype)

    torch.manual_seed(1337)
    if device_type == "cuda":
        torch.cuda.manual_seed(1337)
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True

    # === DATA ===
    get_batch = build_data_loader(
        data_dir=data_dir,
        block_size=block_size,
        batch_size=batch_size,
        device_type=device_type,
        device=device
    )

    # try to infer vocab_size from meta.pkl (like nanoGPT does)
    meta_path = os.path.join(data_dir, "meta.pkl")
    vocab_size = vocab_size_fallback
    if os.path.exists(meta_path):
        with open(meta_path, "rb") as f:
            meta = pickle.load(f)
        if "vocab_size" in meta:
            vocab_size = meta["vocab_size"]

    # === MODEL ===
    gptconf = GPTConfig(
        block_size=block_size,
        vocab_size=vocab_size,
        n_layer=n_layer,
        n_head=n_head,
        n_embd=n_embd,
        dropout=dropout,
        bias=False,
    )
    model = GPT(gptconf).to(device)
    model.train()

    # === OPTIMIZER ===
    # same grouping trick as nanoGPT.configure_optimizers()
    decay_params = [p for p in model.parameters() if p.requires_grad and p.dim() >= 2]
    nodecay_params = [p for p in model.parameters() if p.requires_grad and p.dim() < 2]
    optim_groups = [
        {"params": decay_params,   "weight_decay": weight_decay},
        {"params": nodecay_params, "weight_decay": 0.0},
    ]
    fused_available = "fused" in torch.optim.AdamW.__init__.__code__.co_varnames
    use_fused = fused_available and device_type == "cuda"
    optimizer = torch.optim.AdamW(
        optim_groups,
        lr=learning_rate,
        betas=(beta1, beta2),
        fused=use_fused
    )

    scaler = torch.cuda.amp.GradScaler(enabled=(dtype=="float16"))

    # === LR scheduler ===
    def get_lr(it):
        # warmup
        if it < warmup_iters:
            return learning_rate * (it + 1) / (warmup_iters + 1)
        # cosine decay to ~0
        # (for simplicity we decay to ~0 instead of min_lr here;
        # you can add a min_lr param if you want 6e-5 floor like train.py)
        decay_ratio = (it - warmup_iters) / max(1, (max_iters - warmup_iters))
        decay_ratio = min(max(decay_ratio, 0.0), 1.0)
        coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
        return learning_rate * coeff

    # === W&B logging ===
    import wandb
    wandb.init(
        project=wandb_project,
        name=run_id,
        config={
            "run_id": run_id,
            "n_head": n_head,
            "n_embd": n_embd,
            "batch_size": batch_size,
            "max_iters": max_iters,
            "dropout": dropout,
            "block_size": block_size,
            "n_layer": n_layer,
            "device": device,
        },
    )

    # track best val
    best_val_loss = float("inf")
    best_ckpt_path = os.path.join(out_dir, "ckpt_best.pt")

    t0 = time.time()
    for it in range(max_iters):
        # set lr
        lr = get_lr(it)
        for pg in optimizer.param_groups:
            pg["lr"] = lr

        # fetch batch
        X, Y = get_batch("train")

        # forward
        with ctx:
            logits, loss = model(X, Y)
            loss_val = loss / 1.0  # no grad accumulation here (accum=1)

        # backward
        scaler.scale(loss_val).backward()

        # grad clip
        if grad_clip > 0:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        # step
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad(set_to_none=True)

        # logging loop
        if (it % log_interval == 0) or (it == max_iters - 1):
            # training stats
            loss_float = loss.item()

            # eval stats
            losses = estimate_loss(model, get_batch, eval_iters, ctx)
            train_loss_eval = losses["train"]
            val_loss_eval   = losses["val"]
            loss_gap        = train_loss_eval - val_loss_eval

            # model size / memory
            num_params = count_parameters(model)
            host_mem   = psutil.virtual_memory().percent
            gpu_mem    = gpu_memory_allocated(device)

            dt = time.time() - t0
            t0 = time.time()

            print(f"[{run_id}] iter {it}/{max_iters} | "
                  f"train_now {loss_float:.4f} | "
                  f"train_eval {train_loss_eval:.4f} | "
                  f"val {val_loss_eval:.4f} | "
                  f"gap {loss_gap:.4f} | "
                  f"lr {lr:.2e} | "
                  f"params {num_params/1e6:.2f}M | "
                  f"host_mem {host_mem:.1f}% | "
                  f"gpu_mem {gpu_mem/1e6:.1f}MB | "
                  f"{dt*1000:.1f} ms/it")

            # log to wandb
            wandb.log({
                "iter": it,
                "loss/train_iter": loss_float,              # instant train loss
                "loss/train_eval": train_loss_eval,         # eval() train split
                "loss/val": val_loss_eval,                  # eval() val split
                "loss/gap(train-val)": loss_gap,
                "lr": lr,
                "num_params": num_params,
                "host_mem_percent": host_mem,
                "gpu_mem_bytes": gpu_mem,
            })

            # save best model by val loss
            if val_loss_eval < best_val_loss:
                best_val_loss = val_loss_eval
                torch.save(
                    {
                        "model_state_dict": model.state_dict(),
                        "iter": it,
                        "val_loss": val_loss_eval,
                        "config": {
                            "run_id": run_id,
                            "n_head": n_head,
                            "n_embd": n_embd,
                            "batch_size": batch_size,
                            "max_iters": max_iters,
                            "dropout": dropout,
                            "block_size": block_size,
                            "n_layer": n_layer,
                        },
                    },
                    best_ckpt_path,
                )

    wandb.finish()
    return {
        "run_id": run_id,
        "out_dir": out_dir,
        "best_val_loss": best_val_loss,
        "best_ckpt_path": best_ckpt_path,
        "num_params": count_parameters(model),
    }

print("train_one_experiment() is defined.")
# Out:
# train_one_experiment() is defined.

# %%
# !python data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
# !ls -lh data/shakespeare_char
# Out:
# total 3.3M
# -rw-r--r-- 1 root root 1.1M Oct 28 04:50 input.txt
# -rw-r--r-- 1 root root  703 Oct 28 04:50 meta.pkl
# -rw-r--r-- 1 root root 2.3K Oct 28 04:50 prepare.py
# -rw-r--r-- 1 root root  209 Oct 28 04:50 readme.md
# -rw-r--r-- 1 root root 2.0M Oct 28 04:50 train.bin
# -rw-r--r-- 1 root root 218K Oct 28 04:50 val.bin

# %%
import os
import json
import time
import wandb

# --------- 1. AUTO-LOGIN TO WANDB (no prompt) ---------
os.environ["WANDB_API_KEY"] = "4169865ba6d683df54b62381e15e7896561ee8f1"  # <-- <- <- IMPORTANT
os.environ["WANDB_PROJECT"] = "nanoGPT_Project"           # or any project name you like
os.environ["WANDB_ENTITY"]  = "arunjung1991"                     # optional: your wandb username or team

wandb.login(key=os.environ["WANDB_API_KEY"])

print("wandb logged in as:", wandb.api.api_key[:4] + "...")


# --------- 2. Directory to store sweep summary ---------
os.makedirs("all_experiments", exist_ok=True)
summary_path = os.path.join("all_experiments", "sweep_summary.jsonl")

# we'll append 1 JSON line per finished run so you can come back even if Colab disconnects
def append_summary(result_dict):
    with open(summary_path, "a") as f:
        f.write(json.dumps(result_dict) + "\n")


# --------- 3. Safety helper: GPU memory reset each run ---------
def cleanup_gpu():
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.synchronize()


# --------- 4. Main sweep loop ---------
def run_full_sweep(
    experiment_specs,
    data_dir="data/shakespeare_char",  # <-- change if you're training on a different dataset
    wandb_project="nano-sweep",
    max_runs=None,  # set like 2 to just test; None = run all
):
    results = []
    total_runs = len(experiment_specs) if max_runs is None else min(max_runs, len(experiment_specs))

    print(f"Starting sweep of {total_runs} experiment(s).")

    for run_idx, spec in enumerate(experiment_specs):
        if max_runs is not None and run_idx >= max_runs:
            break

        print("\n" + "="*80)
        print(f" >>> RUN {run_idx+1}/{total_runs}: {spec['run_id']}")
        print("="*80)

        # small sleep just so wandb/rate limits / Colab GPU have a breath between runs
        time.sleep(2)

        # train one experiment using Part 2's function
        try:
            result = train_one_experiment(
                spec,
                data_dir=data_dir,
                wandb_project=wandb_project,
                # you can also override eval_interval, eval_iters, etc. here if needed
            )
        except RuntimeError as e:
            # OOM or other runtime error - record it and continue
            result = {
                "run_id": spec["run_id"],
                "out_dir": spec["out_dir"],
                "error": str(e),
            }
            print(f"[{spec['run_id']}] ERROR DURING TRAINING:", e)

        # persist result to disk immediately
        append_summary(result)
        results.append(result)

        # try to clean up VRAM before next model
        cleanup_gpu()

    print("\nSweep finished.")
    print(f"Sweep summary written line-by-line to {summary_path}")
    return results


# --------- 5. Run it on all 32 (or test with fewer first) ---------
# WARNING: running all 32 sequentially in Colab will take a long time and likely hit runtime limits.
# Start with max_runs=1 or 2 to confirm everything works.

results_preview = run_full_sweep(
    experiment_specs,
    data_dir="data/shakespeare_char",  # make sure this dataset is prepared (train.bin/val.bin/meta.pkl)
    wandb_project="nano-sweep",
    max_runs=None,                        # <-- set to None to do all 32 for real
)

print("Preview results of first few runs:")
print(json.dumps(results_preview, indent=2))
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: arunjung1991 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb logged in as: 4169...
# Starting sweep of 32 experiment(s).
#
# ================================================================================
#  >>> RUN 1/32: exp00_head4_emb128_bs8_it1000_do0.1
# ================================================================================
# number of parameters: 1.19M
# /tmp/ipython-input-2865865035.py:173: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype=="float16"))
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/nanoGPT/wandb/run-20251028_045054-cw3letqf</code>
# Syncing run <strong><a href='https://wandb.ai/arunjung1991/nano-sweep/runs/cw3letqf' target="_blank">exp00_head4_emb128_bs8_it1000_do0.1</a></strong> to <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">https://wandb.ai/arunjung1991/nano-sweep</a>
#  View run at <a href='https://wandb.ai/arunjung1991/nano-sweep/runs/cw3letqf' target="_blank">https://wandb.ai/arunjung1991/nano-sweep/runs/cw3letqf</a>
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 0/1000 | train_now 4.1911 | train_eval 4.1830 | val 4.1794 | gap 0.0035 | lr 5.94e-06 | params 1.21M | host_mem 16.5% | gpu_mem 31.7MB | 1283.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 10/1000 | train_now 3.8013 | train_eval 3.7765 | val 3.7849 | gap -0.0084 | lr 6.53e-05 | params 1.21M | host_mem 16.4% | gpu_mem 31.7MB | 521.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 20/1000 | train_now 3.6570 | train_eval 3.6224 | val 3.6240 | gap -0.0016 | lr 1.25e-04 | params 1.21M | host_mem 16.4% | gpu_mem 31.7MB | 418.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 30/1000 | train_now 3.4199 | train_eval 3.3848 | val 3.3993 | gap -0.0145 | lr 1.84e-04 | params 1.21M | host_mem 16.4% | gpu_mem 31.7MB | 1014.8 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 40/1000 | train_now 3.2136 | train_eval 3.2053 | val 3.2270 | gap -0.0217 | lr 2.44e-04 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 1160.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 50/1000 | train_now 3.0706 | train_eval 3.0468 | val 3.0759 | gap -0.0292 | lr 3.03e-04 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 1035.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 60/1000 | train_now 2.9181 | train_eval 2.9236 | val 2.9503 | gap -0.0267 | lr 3.62e-04 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 461.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 70/1000 | train_now 2.9239 | train_eval 2.8265 | val 2.8518 | gap -0.0253 | lr 4.22e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 442.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 80/1000 | train_now 2.8075 | train_eval 2.7870 | val 2.7888 | gap -0.0019 | lr 4.81e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 414.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 90/1000 | train_now 2.6353 | train_eval 2.7143 | val 2.7356 | gap -0.0213 | lr 5.41e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 428.8 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 100/1000 | train_now 2.6873 | train_eval 2.6717 | val 2.6939 | gap -0.0222 | lr 6.00e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 421.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 110/1000 | train_now 2.6346 | train_eval 2.6540 | val 2.6492 | gap 0.0048 | lr 6.00e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 419.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 120/1000 | train_now 2.6370 | train_eval 2.6129 | val 2.6128 | gap 0.0001 | lr 5.99e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 432.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 130/1000 | train_now 2.5884 | train_eval 2.6209 | val 2.6169 | gap 0.0040 | lr 5.98e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 429.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 140/1000 | train_now 2.6010 | train_eval 2.5914 | val 2.5842 | gap 0.0071 | lr 5.97e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 440.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 150/1000 | train_now 2.6191 | train_eval 2.5747 | val 2.5969 | gap -0.0221 | lr 5.95e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 421.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 160/1000 | train_now 2.5684 | train_eval 2.5797 | val 2.5692 | gap 0.0104 | lr 5.93e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 423.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 170/1000 | train_now 2.5355 | train_eval 2.5761 | val 2.5508 | gap 0.0253 | lr 5.91e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 416.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 180/1000 | train_now 2.5568 | train_eval 2.5449 | val 2.5569 | gap -0.0120 | lr 5.88e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 417.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 190/1000 | train_now 2.5579 | train_eval 2.5587 | val 2.5564 | gap 0.0023 | lr 5.85e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 450.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 200/1000 | train_now 2.5984 | train_eval 2.5535 | val 2.5494 | gap 0.0041 | lr 5.82e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 411.7 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 210/1000 | train_now 2.5430 | train_eval 2.5242 | val 2.5391 | gap -0.0149 | lr 5.78e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 441.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 220/1000 | train_now 2.5823 | train_eval 2.5022 | val 2.5103 | gap -0.0081 | lr 5.74e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 425.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 230/1000 | train_now 2.5003 | train_eval 2.5151 | val 2.5223 | gap -0.0071 | lr 5.70e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 419.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 240/1000 | train_now 2.5207 | train_eval 2.5080 | val 2.5274 | gap -0.0193 | lr 5.65e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 417.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 250/1000 | train_now 2.5555 | train_eval 2.5048 | val 2.5174 | gap -0.0126 | lr 5.60e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 406.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 260/1000 | train_now 2.4577 | train_eval 2.5070 | val 2.5202 | gap -0.0132 | lr 5.54e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 429.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 270/1000 | train_now 2.5116 | train_eval 2.5183 | val 2.5199 | gap -0.0016 | lr 5.49e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 409.7 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 280/1000 | train_now 2.4978 | train_eval 2.4863 | val 2.5007 | gap -0.0144 | lr 5.43e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 418.7 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 290/1000 | train_now 2.5253 | train_eval 2.4819 | val 2.5057 | gap -0.0238 | lr 5.36e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 494.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 300/1000 | train_now 2.5522 | train_eval 2.4873 | val 2.5007 | gap -0.0134 | lr 5.30e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 561.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 310/1000 | train_now 2.5090 | train_eval 2.4933 | val 2.5005 | gap -0.0072 | lr 5.23e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 527.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 320/1000 | train_now 2.5075 | train_eval 2.4583 | val 2.4834 | gap -0.0250 | lr 5.16e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 553.7 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 330/1000 | train_now 2.4669 | train_eval 2.4915 | val 2.4752 | gap 0.0163 | lr 5.08e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 625.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 340/1000 | train_now 2.4631 | train_eval 2.4851 | val 2.4776 | gap 0.0075 | lr 5.01e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 541.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 350/1000 | train_now 2.5569 | train_eval 2.4606 | val 2.4588 | gap 0.0018 | lr 4.93e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 427.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 360/1000 | train_now 2.5214 | train_eval 2.4512 | val 2.4593 | gap -0.0081 | lr 4.85e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 462.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 370/1000 | train_now 2.5540 | train_eval 2.4527 | val 2.4538 | gap -0.0011 | lr 4.76e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 426.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 380/1000 | train_now 2.4770 | train_eval 2.4502 | val 2.4654 | gap -0.0152 | lr 4.68e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 414.8 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 390/1000 | train_now 2.4459 | train_eval 2.4564 | val 2.4600 | gap -0.0037 | lr 4.59e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 416.7 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 400/1000 | train_now 2.4095 | train_eval 2.4311 | val 2.4446 | gap -0.0135 | lr 4.50e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 421.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 410/1000 | train_now 2.4193 | train_eval 2.4511 | val 2.4634 | gap -0.0123 | lr 4.41e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 446.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 420/1000 | train_now 2.4290 | train_eval 2.4446 | val 2.4422 | gap 0.0024 | lr 4.32e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 421.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 430/1000 | train_now 2.3790 | train_eval 2.4272 | val 2.4324 | gap -0.0052 | lr 4.22e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 418.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 440/1000 | train_now 2.4661 | train_eval 2.4199 | val 2.4259 | gap -0.0061 | lr 4.12e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 424.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 450/1000 | train_now 2.4204 | train_eval 2.4060 | val 2.4183 | gap -0.0124 | lr 4.03e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 420.7 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 460/1000 | train_now 2.4420 | train_eval 2.4257 | val 2.4213 | gap 0.0044 | lr 3.93e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 417.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 470/1000 | train_now 2.4037 | train_eval 2.4222 | val 2.4281 | gap -0.0059 | lr 3.83e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 421.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 480/1000 | train_now 2.4590 | train_eval 2.4153 | val 2.4156 | gap -0.0003 | lr 3.73e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 401.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 490/1000 | train_now 2.3845 | train_eval 2.4244 | val 2.4316 | gap -0.0072 | lr 3.62e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 416.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 500/1000 | train_now 2.3736 | train_eval 2.4074 | val 2.4240 | gap -0.0167 | lr 3.52e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 400.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 510/1000 | train_now 2.4044 | train_eval 2.4004 | val 2.4059 | gap -0.0055 | lr 3.42e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 409.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 520/1000 | train_now 2.4230 | train_eval 2.4166 | val 2.4424 | gap -0.0257 | lr 3.31e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 444.8 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 530/1000 | train_now 2.4646 | train_eval 2.4136 | val 2.4154 | gap -0.0017 | lr 3.21e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 420.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 540/1000 | train_now 2.4267 | train_eval 2.3990 | val 2.4015 | gap -0.0025 | lr 3.10e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 424.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 550/1000 | train_now 2.4527 | train_eval 2.4021 | val 2.4097 | gap -0.0076 | lr 3.00e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 424.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 560/1000 | train_now 2.4282 | train_eval 2.3929 | val 2.4110 | gap -0.0182 | lr 2.90e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 403.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 570/1000 | train_now 2.4204 | train_eval 2.3955 | val 2.3914 | gap 0.0041 | lr 2.79e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 426.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 580/1000 | train_now 2.3968 | train_eval 2.4048 | val 2.4017 | gap 0.0032 | lr 2.69e-04 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 544.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 590/1000 | train_now 2.3979 | train_eval 2.4010 | val 2.3912 | gap 0.0098 | lr 2.58e-04 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 551.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 600/1000 | train_now 2.4955 | train_eval 2.4047 | val 2.4032 | gap 0.0014 | lr 2.48e-04 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 605.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 610/1000 | train_now 2.3894 | train_eval 2.3740 | val 2.4066 | gap -0.0326 | lr 2.38e-04 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 613.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 620/1000 | train_now 2.3489 | train_eval 2.3779 | val 2.3874 | gap -0.0095 | lr 2.27e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 632.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 630/1000 | train_now 2.4451 | train_eval 2.3719 | val 2.3607 | gap 0.0111 | lr 2.17e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 431.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 640/1000 | train_now 2.4317 | train_eval 2.3886 | val 2.3689 | gap 0.0197 | lr 2.07e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 422.8 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 650/1000 | train_now 2.4046 | train_eval 2.3664 | val 2.3639 | gap 0.0025 | lr 1.97e-04 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 429.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 660/1000 | train_now 2.3661 | train_eval 2.3723 | val 2.3746 | gap -0.0023 | lr 1.88e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 419.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 670/1000 | train_now 2.3876 | train_eval 2.3597 | val 2.3660 | gap -0.0063 | lr 1.78e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 426.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 680/1000 | train_now 2.3466 | train_eval 2.3752 | val 2.3626 | gap 0.0126 | lr 1.68e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 411.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 690/1000 | train_now 2.3890 | train_eval 2.3614 | val 2.3664 | gap -0.0050 | lr 1.59e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 415.8 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 700/1000 | train_now 2.4813 | train_eval 2.3571 | val 2.3415 | gap 0.0156 | lr 1.50e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 424.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 710/1000 | train_now 2.4483 | train_eval 2.3642 | val 2.3620 | gap 0.0022 | lr 1.41e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 419.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 720/1000 | train_now 2.3834 | train_eval 2.3504 | val 2.3489 | gap 0.0015 | lr 1.32e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 419.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 730/1000 | train_now 2.3549 | train_eval 2.3509 | val 2.3465 | gap 0.0044 | lr 1.24e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 401.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 740/1000 | train_now 2.3509 | train_eval 2.3498 | val 2.3466 | gap 0.0032 | lr 1.15e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 453.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 750/1000 | train_now 2.3121 | train_eval 2.3345 | val 2.3323 | gap 0.0022 | lr 1.07e-04 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 432.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 760/1000 | train_now 2.3456 | train_eval 2.3582 | val 2.3422 | gap 0.0161 | lr 9.93e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 423.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 770/1000 | train_now 2.3701 | train_eval 2.3333 | val 2.3408 | gap -0.0075 | lr 9.16e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 455.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 780/1000 | train_now 2.3485 | train_eval 2.3240 | val 2.3255 | gap -0.0015 | lr 8.42e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 426.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 790/1000 | train_now 2.3583 | train_eval 2.3365 | val 2.3470 | gap -0.0105 | lr 7.71e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 438.8 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 800/1000 | train_now 2.3799 | train_eval 2.3406 | val 2.3267 | gap 0.0138 | lr 7.02e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 410.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 810/1000 | train_now 2.3139 | train_eval 2.3243 | val 2.3400 | gap -0.0157 | lr 6.36e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 410.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 820/1000 | train_now 2.3636 | train_eval 2.3256 | val 2.3167 | gap 0.0089 | lr 5.73e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 430.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 830/1000 | train_now 2.3588 | train_eval 2.3383 | val 2.3342 | gap 0.0040 | lr 5.13e-05 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 431.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 840/1000 | train_now 2.3473 | train_eval 2.3226 | val 2.3295 | gap -0.0069 | lr 4.56e-05 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 423.9 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 850/1000 | train_now 2.4169 | train_eval 2.3302 | val 2.3267 | gap 0.0035 | lr 4.02e-05 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 418.2 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 860/1000 | train_now 2.3659 | train_eval 2.3233 | val 2.3237 | gap -0.0004 | lr 3.51e-05 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 539.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 870/1000 | train_now 2.3530 | train_eval 2.3213 | val 2.3345 | gap -0.0132 | lr 3.04e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 546.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 880/1000 | train_now 2.3056 | train_eval 2.3191 | val 2.3104 | gap 0.0087 | lr 2.59e-05 | params 1.21M | host_mem 16.1% | gpu_mem 31.7MB | 530.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 890/1000 | train_now 2.2715 | train_eval 2.3166 | val 2.3098 | gap 0.0068 | lr 2.18e-05 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 617.6 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 900/1000 | train_now 2.4342 | train_eval 2.3234 | val 2.3247 | gap -0.0012 | lr 1.81e-05 | params 1.21M | host_mem 16.0% | gpu_mem 31.7MB | 703.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 910/1000 | train_now 2.3178 | train_eval 2.2987 | val 2.3150 | gap -0.0163 | lr 1.47e-05 | params 1.21M | host_mem 16.2% | gpu_mem 31.7MB | 677.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 920/1000 | train_now 2.3659 | train_eval 2.3165 | val 2.3324 | gap -0.0159 | lr 1.16e-05 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 630.0 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 930/1000 | train_now 2.4502 | train_eval 2.3206 | val 2.3190 | gap 0.0016 | lr 8.91e-06 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 560.3 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 940/1000 | train_now 2.3358 | train_eval 2.3154 | val 2.3149 | gap 0.0004 | lr 6.56e-06 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 590.8 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 950/1000 | train_now 2.3496 | train_eval 2.3285 | val 2.2987 | gap 0.0297 | lr 4.56e-06 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 430.7 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 960/1000 | train_now 2.3453 | train_eval 2.3277 | val 2.3087 | gap 0.0190 | lr 2.92e-06 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 447.4 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 970/1000 | train_now 2.3953 | train_eval 2.3203 | val 2.3341 | gap -0.0139 | lr 1.64e-06 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 410.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 980/1000 | train_now 2.4071 | train_eval 2.3176 | val 2.3413 | gap -0.0238 | lr 7.31e-07 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 400.1 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 990/1000 | train_now 2.3365 | train_eval 2.3193 | val 2.3288 | gap -0.0095 | lr 1.83e-07 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 418.5 ms/it
# [exp00_head4_emb128_bs8_it1000_do0.1] iter 999/1000 | train_now 2.3303 | train_eval 2.3067 | val 2.3251 | gap -0.0184 | lr 1.83e-09 | params 1.21M | host_mem 16.3% | gpu_mem 31.7MB | 386.6 ms/it
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gpu_mem_bytes</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>host_mem_percent</td><td>██▆▅▃▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▃▅▁▁▃▃▃▃▃▃▃▃▁▆▆▆▆</td></tr><tr><td>iter</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss/gap(train-val)</td><td>▄▃▁▆▅▆▇▃▅▃▂▃▃▃▁▅▄▃▄▃▃▄▄▄▂▅▇█▅▅▃▇▂▅▃▆▂▂▅▁</td></tr><tr><td>loss/train_eval</td><td>█▆▆▅▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss/train_iter</td><td>█▇▆▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss/val</td><td>█▇▆▅▄▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>▂▃▄▅▆▇████▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▄▄▄▄▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>num_params</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gpu_mem_bytes</td><td>31682048</td></tr><tr><td>host_mem_percent</td><td>16.3</td></tr><tr><td>iter</td><td>999</td></tr><tr><td>loss/gap(train-val)</td><td>-0.01839</td></tr><tr><td>loss/train_eval</td><td>2.30672</td></tr><tr><td>loss/train_iter</td><td>2.33032</td></tr><tr><td>loss/val</td><td>2.32512</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>num_params</td><td>1206016</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exp00_head4_emb128_bs8_it1000_do0.1</strong> at: <a href='https://wandb.ai/arunjung1991/nano-sweep/runs/cw3letqf' target="_blank">https://wandb.ai/arunjung1991/nano-sweep/runs/cw3letqf</a><br> View project at: <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">https://wandb.ai/arunjung1991/nano-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251028_045054-cw3letqf/logs</code>
# ================================================================================
#  >>> RUN 2/32: exp01_head4_emb128_bs8_it1000_do0.2
# ================================================================================
# number of parameters: 1.19M
# /tmp/ipython-input-2865865035.py:173: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype=="float16"))
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/nanoGPT/wandb/run-20251028_045148-hkysh6fw</code>
# Syncing run <strong><a href='https://wandb.ai/arunjung1991/nano-sweep/runs/hkysh6fw' target="_blank">exp01_head4_emb128_bs8_it1000_do0.2</a></strong> to <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">https://wandb.ai/arunjung1991/nano-sweep</a>
#  View run at <a href='https://wandb.ai/arunjung1991/nano-sweep/runs/hkysh6fw' target="_blank">https://wandb.ai/arunjung1991/nano-sweep/runs/hkysh6fw</a>
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 0/1000 | train_now 4.1932 | train_eval 4.1835 | val 4.1798 | gap 0.0036 | lr 5.94e-06 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 279.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 10/1000 | train_now 3.8223 | train_eval 3.7833 | val 3.7920 | gap -0.0087 | lr 6.53e-05 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 434.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 20/1000 | train_now 3.6810 | train_eval 3.6473 | val 3.6525 | gap -0.0053 | lr 1.25e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 418.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 30/1000 | train_now 3.4656 | train_eval 3.4169 | val 3.4296 | gap -0.0126 | lr 1.84e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 540.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 40/1000 | train_now 3.2548 | train_eval 3.2245 | val 3.2463 | gap -0.0218 | lr 2.44e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 558.7 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 50/1000 | train_now 3.1054 | train_eval 3.0635 | val 3.0974 | gap -0.0339 | lr 3.03e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 565.7 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 60/1000 | train_now 2.9526 | train_eval 2.9391 | val 2.9644 | gap -0.0252 | lr 3.62e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 580.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 70/1000 | train_now 2.9630 | train_eval 2.8360 | val 2.8639 | gap -0.0279 | lr 4.22e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 647.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 80/1000 | train_now 2.8477 | train_eval 2.7994 | val 2.8048 | gap -0.0053 | lr 4.81e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 454.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 90/1000 | train_now 2.6704 | train_eval 2.7272 | val 2.7474 | gap -0.0202 | lr 5.41e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 427.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 100/1000 | train_now 2.7088 | train_eval 2.6768 | val 2.6996 | gap -0.0228 | lr 6.00e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 427.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 110/1000 | train_now 2.6572 | train_eval 2.6583 | val 2.6528 | gap 0.0055 | lr 6.00e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 450.7 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 120/1000 | train_now 2.6588 | train_eval 2.6255 | val 2.6236 | gap 0.0019 | lr 5.99e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 413.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 130/1000 | train_now 2.6168 | train_eval 2.6232 | val 2.6178 | gap 0.0054 | lr 5.98e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 439.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 140/1000 | train_now 2.6185 | train_eval 2.5968 | val 2.5921 | gap 0.0047 | lr 5.97e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 430.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 150/1000 | train_now 2.6366 | train_eval 2.5802 | val 2.6041 | gap -0.0239 | lr 5.95e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 426.7 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 160/1000 | train_now 2.5890 | train_eval 2.5915 | val 2.5792 | gap 0.0123 | lr 5.93e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 421.6 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 170/1000 | train_now 2.5564 | train_eval 2.5928 | val 2.5691 | gap 0.0238 | lr 5.91e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 412.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 180/1000 | train_now 2.5813 | train_eval 2.5598 | val 2.5704 | gap -0.0107 | lr 5.88e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 420.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 190/1000 | train_now 2.5827 | train_eval 2.5734 | val 2.5674 | gap 0.0059 | lr 5.85e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 458.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 200/1000 | train_now 2.6119 | train_eval 2.5586 | val 2.5502 | gap 0.0084 | lr 5.82e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 408.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 210/1000 | train_now 2.5758 | train_eval 2.5406 | val 2.5543 | gap -0.0137 | lr 5.78e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 431.6 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 220/1000 | train_now 2.6004 | train_eval 2.5167 | val 2.5209 | gap -0.0043 | lr 5.74e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 405.6 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 230/1000 | train_now 2.5282 | train_eval 2.5278 | val 2.5329 | gap -0.0052 | lr 5.70e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 415.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 240/1000 | train_now 2.5428 | train_eval 2.5193 | val 2.5355 | gap -0.0163 | lr 5.65e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 420.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 250/1000 | train_now 2.5716 | train_eval 2.5264 | val 2.5296 | gap -0.0032 | lr 5.60e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 403.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 260/1000 | train_now 2.4910 | train_eval 2.5079 | val 2.5171 | gap -0.0092 | lr 5.54e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 416.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 270/1000 | train_now 2.5235 | train_eval 2.5215 | val 2.5258 | gap -0.0043 | lr 5.49e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 419.4 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 280/1000 | train_now 2.5228 | train_eval 2.5052 | val 2.5153 | gap -0.0101 | lr 5.43e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 403.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 290/1000 | train_now 2.5547 | train_eval 2.4982 | val 2.5162 | gap -0.0180 | lr 5.36e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 425.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 300/1000 | train_now 2.5846 | train_eval 2.5095 | val 2.5250 | gap -0.0155 | lr 5.30e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 414.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 310/1000 | train_now 2.5417 | train_eval 2.5047 | val 2.5226 | gap -0.0179 | lr 5.23e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 470.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 320/1000 | train_now 2.5318 | train_eval 2.4757 | val 2.5010 | gap -0.0254 | lr 5.16e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 533.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 330/1000 | train_now 2.4801 | train_eval 2.5185 | val 2.4972 | gap 0.0213 | lr 5.08e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 549.6 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 340/1000 | train_now 2.5049 | train_eval 2.5096 | val 2.5006 | gap 0.0090 | lr 5.01e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 557.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 350/1000 | train_now 2.5755 | train_eval 2.4818 | val 2.4868 | gap -0.0050 | lr 4.93e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 589.4 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 360/1000 | train_now 2.5459 | train_eval 2.4655 | val 2.4721 | gap -0.0066 | lr 4.85e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 558.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 370/1000 | train_now 2.5889 | train_eval 2.4647 | val 2.4674 | gap -0.0027 | lr 4.76e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 465.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 380/1000 | train_now 2.4991 | train_eval 2.4657 | val 2.4842 | gap -0.0185 | lr 4.68e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 429.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 390/1000 | train_now 2.4697 | train_eval 2.4836 | val 2.4876 | gap -0.0039 | lr 4.59e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 437.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 400/1000 | train_now 2.4387 | train_eval 2.4511 | val 2.4740 | gap -0.0229 | lr 4.50e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 442.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 410/1000 | train_now 2.4612 | train_eval 2.4756 | val 2.4906 | gap -0.0150 | lr 4.41e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 420.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 420/1000 | train_now 2.4480 | train_eval 2.4702 | val 2.4674 | gap 0.0028 | lr 4.32e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 436.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 430/1000 | train_now 2.4171 | train_eval 2.4523 | val 2.4555 | gap -0.0032 | lr 4.22e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 425.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 440/1000 | train_now 2.4956 | train_eval 2.4431 | val 2.4489 | gap -0.0058 | lr 4.12e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 433.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 450/1000 | train_now 2.4462 | train_eval 2.4293 | val 2.4403 | gap -0.0110 | lr 4.03e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 418.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 460/1000 | train_now 2.4665 | train_eval 2.4461 | val 2.4391 | gap 0.0070 | lr 3.93e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 432.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 470/1000 | train_now 2.4330 | train_eval 2.4487 | val 2.4532 | gap -0.0045 | lr 3.83e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 416.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 480/1000 | train_now 2.4682 | train_eval 2.4393 | val 2.4399 | gap -0.0007 | lr 3.73e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 409.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 490/1000 | train_now 2.3984 | train_eval 2.4507 | val 2.4554 | gap -0.0046 | lr 3.62e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 428.7 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 500/1000 | train_now 2.4120 | train_eval 2.4381 | val 2.4510 | gap -0.0129 | lr 3.52e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 403.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 510/1000 | train_now 2.4430 | train_eval 2.4229 | val 2.4279 | gap -0.0050 | lr 3.42e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 425.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 520/1000 | train_now 2.4469 | train_eval 2.4439 | val 2.4765 | gap -0.0326 | lr 3.31e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 425.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 530/1000 | train_now 2.4902 | train_eval 2.4432 | val 2.4475 | gap -0.0043 | lr 3.21e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 401.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 540/1000 | train_now 2.4830 | train_eval 2.4350 | val 2.4356 | gap -0.0006 | lr 3.10e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 421.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 550/1000 | train_now 2.4845 | train_eval 2.4333 | val 2.4406 | gap -0.0072 | lr 3.00e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 402.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 560/1000 | train_now 2.4711 | train_eval 2.4270 | val 2.4422 | gap -0.0152 | lr 2.90e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 444.4 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 570/1000 | train_now 2.4622 | train_eval 2.4270 | val 2.4215 | gap 0.0055 | lr 2.79e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 402.4 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 580/1000 | train_now 2.4384 | train_eval 2.4331 | val 2.4247 | gap 0.0084 | lr 2.69e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 420.4 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 590/1000 | train_now 2.4285 | train_eval 2.4326 | val 2.4213 | gap 0.0112 | lr 2.58e-04 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 423.6 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 600/1000 | train_now 2.5221 | train_eval 2.4365 | val 2.4387 | gap -0.0023 | lr 2.48e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 574.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 610/1000 | train_now 2.4149 | train_eval 2.4119 | val 2.4445 | gap -0.0326 | lr 2.38e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 533.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 620/1000 | train_now 2.3865 | train_eval 2.4123 | val 2.4165 | gap -0.0042 | lr 2.27e-04 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 516.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 630/1000 | train_now 2.4957 | train_eval 2.4192 | val 2.4042 | gap 0.0150 | lr 2.17e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 589.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 640/1000 | train_now 2.4636 | train_eval 2.4292 | val 2.4097 | gap 0.0195 | lr 2.07e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 622.7 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 650/1000 | train_now 2.4338 | train_eval 2.4033 | val 2.4025 | gap 0.0008 | lr 1.97e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 424.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 660/1000 | train_now 2.4177 | train_eval 2.4069 | val 2.4076 | gap -0.0007 | lr 1.88e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 426.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 670/1000 | train_now 2.4322 | train_eval 2.4013 | val 2.4038 | gap -0.0025 | lr 1.78e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 424.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 680/1000 | train_now 2.3960 | train_eval 2.4142 | val 2.3984 | gap 0.0158 | lr 1.68e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 408.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 690/1000 | train_now 2.4243 | train_eval 2.4046 | val 2.4045 | gap 0.0001 | lr 1.59e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 420.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 700/1000 | train_now 2.5151 | train_eval 2.3996 | val 2.3797 | gap 0.0199 | lr 1.50e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 419.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 710/1000 | train_now 2.4858 | train_eval 2.4145 | val 2.4058 | gap 0.0087 | lr 1.41e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 424.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 720/1000 | train_now 2.4265 | train_eval 2.3974 | val 2.3938 | gap 0.0035 | lr 1.32e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 418.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 730/1000 | train_now 2.3932 | train_eval 2.3975 | val 2.3902 | gap 0.0073 | lr 1.24e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 414.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 740/1000 | train_now 2.4129 | train_eval 2.4012 | val 2.3975 | gap 0.0037 | lr 1.15e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 409.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 750/1000 | train_now 2.3811 | train_eval 2.3852 | val 2.3820 | gap 0.0032 | lr 1.07e-04 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 417.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 760/1000 | train_now 2.4021 | train_eval 2.4096 | val 2.3863 | gap 0.0233 | lr 9.93e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 410.5 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 770/1000 | train_now 2.4229 | train_eval 2.3870 | val 2.3920 | gap -0.0051 | lr 9.16e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 414.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 780/1000 | train_now 2.4082 | train_eval 2.3769 | val 2.3691 | gap 0.0077 | lr 8.42e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 424.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 790/1000 | train_now 2.4162 | train_eval 2.3848 | val 2.3915 | gap -0.0068 | lr 7.71e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 426.9 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 800/1000 | train_now 2.4208 | train_eval 2.3939 | val 2.3781 | gap 0.0158 | lr 7.02e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 411.4 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 810/1000 | train_now 2.3813 | train_eval 2.3784 | val 2.3895 | gap -0.0111 | lr 6.36e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 408.4 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 820/1000 | train_now 2.4397 | train_eval 2.3791 | val 2.3685 | gap 0.0106 | lr 5.73e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 428.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 830/1000 | train_now 2.3905 | train_eval 2.3936 | val 2.3852 | gap 0.0085 | lr 5.13e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 424.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 840/1000 | train_now 2.4094 | train_eval 2.3810 | val 2.3769 | gap 0.0041 | lr 4.56e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 413.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 850/1000 | train_now 2.4381 | train_eval 2.3880 | val 2.3776 | gap 0.0104 | lr 4.02e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 408.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 860/1000 | train_now 2.4265 | train_eval 2.3802 | val 2.3763 | gap 0.0039 | lr 3.51e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 408.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 870/1000 | train_now 2.3965 | train_eval 2.3789 | val 2.3877 | gap -0.0088 | lr 3.04e-05 | params 1.21M | host_mem 16.3% | gpu_mem 36.5MB | 418.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 880/1000 | train_now 2.3769 | train_eval 2.3787 | val 2.3633 | gap 0.0154 | lr 2.59e-05 | params 1.21M | host_mem 16.1% | gpu_mem 36.5MB | 514.7 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 890/1000 | train_now 2.3417 | train_eval 2.3789 | val 2.3629 | gap 0.0160 | lr 2.18e-05 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 587.7 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 900/1000 | train_now 2.5095 | train_eval 2.3819 | val 2.3787 | gap 0.0032 | lr 1.81e-05 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 534.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 910/1000 | train_now 2.3835 | train_eval 2.3574 | val 2.3705 | gap -0.0130 | lr 1.47e-05 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 551.6 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 920/1000 | train_now 2.4188 | train_eval 2.3772 | val 2.3897 | gap -0.0125 | lr 1.16e-05 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 577.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 930/1000 | train_now 2.5055 | train_eval 2.3809 | val 2.3745 | gap 0.0064 | lr 8.91e-06 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 523.1 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 940/1000 | train_now 2.3950 | train_eval 2.3738 | val 2.3708 | gap 0.0031 | lr 6.56e-06 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 409.3 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 950/1000 | train_now 2.4004 | train_eval 2.3857 | val 2.3532 | gap 0.0325 | lr 4.56e-06 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 420.4 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 960/1000 | train_now 2.3916 | train_eval 2.3868 | val 2.3638 | gap 0.0230 | lr 2.92e-06 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 417.2 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 970/1000 | train_now 2.4611 | train_eval 2.3770 | val 2.3852 | gap -0.0082 | lr 1.64e-06 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 404.0 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 980/1000 | train_now 2.4685 | train_eval 2.3771 | val 2.3942 | gap -0.0171 | lr 7.31e-07 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 427.6 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 990/1000 | train_now 2.4098 | train_eval 2.3760 | val 2.3853 | gap -0.0093 | lr 1.83e-07 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 410.8 ms/it
# [exp01_head4_emb128_bs8_it1000_do0.2] iter 999/1000 | train_now 2.3806 | train_eval 2.3668 | val 2.3793 | gap -0.0125 | lr 1.83e-09 | params 1.21M | host_mem 16.2% | gpu_mem 36.5MB | 423.3 ms/it
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gpu_mem_bytes</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>host_mem_percent</td><td>▁▁▅▅▅██████▅▅▅▅▅█▁▁▁▁▁▁▁▁██████████▅▅▅▅▅</td></tr><tr><td>iter</td><td>▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss/gap(train-val)</td><td>▄▄▁▂▅▃▅▅▄▄▃▂▇▅▄▅▄▄▃▄▄▅▅▄▁▅▄▄▆▅▄▆▆▅▄▅▃▅█▃</td></tr><tr><td>loss/train_eval</td><td>█▆▆▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss/train_iter</td><td>█▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▂▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁▂▂▁</td></tr><tr><td>loss/val</td><td>█▆▄▄▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>▁▂▅▅▆████▇▇▇▇▆▆▅▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>num_params</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gpu_mem_bytes</td><td>36506112</td></tr><tr><td>host_mem_percent</td><td>16.2</td></tr><tr><td>iter</td><td>999</td></tr><tr><td>loss/gap(train-val)</td><td>-0.01249</td></tr><tr><td>loss/train_eval</td><td>2.36679</td></tr><tr><td>loss/train_iter</td><td>2.38063</td></tr><tr><td>loss/val</td><td>2.37928</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>num_params</td><td>1206016</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exp01_head4_emb128_bs8_it1000_do0.2</strong> at: <a href='https://wandb.ai/arunjung1991/nano-sweep/runs/hkysh6fw' target="_blank">https://wandb.ai/arunjung1991/nano-sweep/runs/hkysh6fw</a><br> View project at: <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">https://wandb.ai/arunjung1991/nano-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251028_045148-hkysh6fw/logs</code>
# ================================================================================
#  >>> RUN 3/32: exp02_head4_emb128_bs8_it2000_do0.1
# ================================================================================
# number of parameters: 1.19M
# /tmp/ipython-input-2865865035.py:173: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype=="float16"))
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/nanoGPT/wandb/run-20251028_045238-bzgj2il5</code>
# Syncing run <strong><a href='https://wandb.ai/arunjung1991/nano-sweep/runs/bzgj2il5' target="_blank">exp02_head4_emb128_bs8_it2000_do0.1</a></strong> to <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">https://wandb.ai/arunjung1991/nano-sweep</a>
# ...
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1800/2000 | train_now 1.8503 | train_eval 1.7583 | val 1.8848 | gap -0.1265 | lr 1.63e-05 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 924.7 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1810/2000 | train_now 1.8559 | train_eval 1.7518 | val 1.8833 | gap -0.1315 | lr 1.47e-05 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 897.4 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1820/2000 | train_now 1.8416 | train_eval 1.7548 | val 1.8792 | gap -0.1245 | lr 1.32e-05 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 898.2 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1830/2000 | train_now 1.7463 | train_eval 1.7673 | val 1.8954 | gap -0.1280 | lr 1.18e-05 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 923.3 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1840/2000 | train_now 1.8461 | train_eval 1.7535 | val 1.8875 | gap -0.1340 | lr 1.04e-05 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 897.5 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1850/2000 | train_now 1.8917 | train_eval 1.7427 | val 1.8907 | gap -0.1480 | lr 9.18e-06 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 911.2 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1860/2000 | train_now 1.8968 | train_eval 1.7413 | val 1.9029 | gap -0.1616 | lr 8.00e-06 | params 4.77M | host_mem 17.9% | gpu_mem 146.3MB | 904.9 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1870/2000 | train_now 1.8707 | train_eval 1.7738 | val 1.8933 | gap -0.1196 | lr 6.90e-06 | params 4.77M | host_mem 17.9% | gpu_mem 146.3MB | 912.7 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1880/2000 | train_now 1.8667 | train_eval 1.7612 | val 1.8870 | gap -0.1257 | lr 5.89e-06 | params 4.77M | host_mem 17.9% | gpu_mem 146.3MB | 896.4 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1890/2000 | train_now 1.8205 | train_eval 1.7530 | val 1.8827 | gap -0.1297 | lr 4.95e-06 | params 4.77M | host_mem 17.9% | gpu_mem 146.3MB | 900.1 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1900/2000 | train_now 1.8832 | train_eval 1.7451 | val 1.9038 | gap -0.1587 | lr 4.09e-06 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 899.1 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1910/2000 | train_now 1.8359 | train_eval 1.7705 | val 1.8817 | gap -0.1112 | lr 3.32e-06 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 897.0 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1920/2000 | train_now 1.8749 | train_eval 1.7555 | val 1.8875 | gap -0.1320 | lr 2.62e-06 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 899.9 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1930/2000 | train_now 1.8532 | train_eval 1.7343 | val 1.8908 | gap -0.1565 | lr 2.01e-06 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 897.1 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1940/2000 | train_now 1.8584 | train_eval 1.7571 | val 1.9103 | gap -0.1532 | lr 1.48e-06 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 898.5 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1950/2000 | train_now 2.0045 | train_eval 1.7354 | val 1.8777 | gap -0.1423 | lr 1.02e-06 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 898.5 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1960/2000 | train_now 1.8486 | train_eval 1.7595 | val 1.8844 | gap -0.1249 | lr 6.56e-07 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 922.1 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1970/2000 | train_now 1.8515 | train_eval 1.7576 | val 1.8893 | gap -0.1317 | lr 3.69e-07 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 895.1 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1980/2000 | train_now 1.7347 | train_eval 1.7622 | val 1.8954 | gap -0.1332 | lr 1.64e-07 | params 4.77M | host_mem 17.8% | gpu_mem 146.3MB | 901.0 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1990/2000 | train_now 1.8041 | train_eval 1.7655 | val 1.8910 | gap -0.1255 | lr 4.10e-08 | params 4.77M | host_mem 17.9% | gpu_mem 146.3MB | 912.9 ms/it
# [exp31_head8_emb256_bs16_it2000_do0.2] iter 1999/2000 | train_now 1.8520 | train_eval 1.7464 | val 1.9081 | gap -0.1617 | lr 4.10e-10 | params 4.77M | host_mem 17.9% | gpu_mem 146.3MB | 874.7 ms/it
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>gpu_mem_bytes</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>host_mem_percent</td><td>▆█▆▁▆▆▆▆▆▆▆▆▆█▆▆▆▆█▆▆▆█▆▆▆▆▆█▆▆█▆▆▆▆▆▆▆█</td></tr><tr><td>iter</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss/gap(train-val)</td><td>██▇▇█▆▆▇▆▆▆▇▆▆▅▆▅▆▄▄▄▄▃▄▂▃▃▃▂▃▃▂▂▁▂▂▂▃▂▁</td></tr><tr><td>loss/train_eval</td><td>█▇▆▆▆▆▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss/train_iter</td><td>██▇▇▆▆▆▆▅▅▅▅▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▁▂▂▂▂▂▂▂▂▂▂▁▂</td></tr><tr><td>loss/val</td><td>███▇▇▇▇▆▆▆▆▆▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>▅▆▇███████▇▇▇▆▆▆▆▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>num_params</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>gpu_mem_bytes</td><td>146343424</td></tr><tr><td>host_mem_percent</td><td>17.9</td></tr><tr><td>iter</td><td>1999</td></tr><tr><td>loss/gap(train-val)</td><td>-0.16172</td></tr><tr><td>loss/train_eval</td><td>1.7464</td></tr><tr><td>loss/train_iter</td><td>1.85203</td></tr><tr><td>loss/val</td><td>1.90811</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>num_params</td><td>4771328</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exp31_head8_emb256_bs16_it2000_do0.2</strong> at: <a href='https://wandb.ai/arunjung1991/nano-sweep/runs/htebl6gj' target="_blank">https://wandb.ai/arunjung1991/nano-sweep/runs/htebl6gj</a><br> View project at: <a href='https://wandb.ai/arunjung1991/nano-sweep' target="_blank">https://wandb.ai/arunjung1991/nano-sweep</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251028_053740-htebl6gj/logs</code>
# Sweep finished.
# Sweep summary written line-by-line to all_experiments/sweep_summary.jsonl
# Preview results of first few runs:
# [
#   {
#     "run_id": "exp00_head4_emb128_bs8_it1000_do0.1",
#     "out_dir": "all_experiments/exp00_head4_emb128_bs8_it1000_do0.1",
#     "best_val_loss": 2.2987210631370543,
#     "best_ckpt_path": "all_experiments/exp00_head4_emb128_bs8_it1000_do0.1/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp01_head4_emb128_bs8_it1000_do0.2",
#     "out_dir": "all_experiments/exp01_head4_emb128_bs8_it1000_do0.2",
#     "best_val_loss": 2.353180992603302,
#     "best_ckpt_path": "all_experiments/exp01_head4_emb128_bs8_it1000_do0.2/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp02_head4_emb128_bs8_it2000_do0.1",
#     "out_dir": "all_experiments/exp02_head4_emb128_bs8_it2000_do0.1",
#     "best_val_loss": 2.1426128268241884,
#     "best_ckpt_path": "all_experiments/exp02_head4_emb128_bs8_it2000_do0.1/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp03_head4_emb128_bs8_it2000_do0.2",
#     "out_dir": "all_experiments/exp03_head4_emb128_bs8_it2000_do0.2",
#     "best_val_loss": 2.209380638599396,
#     "best_ckpt_path": "all_experiments/exp03_head4_emb128_bs8_it2000_do0.2/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp04_head4_emb128_bs16_it1000_do0.1",
#     "out_dir": "all_experiments/exp04_head4_emb128_bs16_it1000_do0.1",
#     "best_val_loss": 2.224496078491211,
#     "best_ckpt_path": "all_experiments/exp04_head4_emb128_bs16_it1000_do0.1/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp05_head4_emb128_bs16_it1000_do0.2",
#     "out_dir": "all_experiments/exp05_head4_emb128_bs16_it1000_do0.2",
#     "best_val_loss": 2.276405668258667,
#     "best_ckpt_path": "all_experiments/exp05_head4_emb128_bs16_it1000_do0.2/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp06_head4_emb128_bs16_it2000_do0.1",
#     "out_dir": "all_experiments/exp06_head4_emb128_bs16_it2000_do0.1",
#     "best_val_loss": 1.9852119982242584,
#     "best_ckpt_path": "all_experiments/exp06_head4_emb128_bs16_it2000_do0.1/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp07_head4_emb128_bs16_it2000_do0.2",
#     "out_dir": "all_experiments/exp07_head4_emb128_bs16_it2000_do0.2",
#     "best_val_loss": 2.0710054874420165,
#     "best_ckpt_path": "all_experiments/exp07_head4_emb128_bs16_it2000_do0.2/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp08_head4_emb256_bs8_it1000_do0.1",
#     "out_dir": "all_experiments/exp08_head4_emb256_bs8_it1000_do0.1",
#     "best_val_loss": 2.185921275615692,
#     "best_ckpt_path": "all_experiments/exp08_head4_emb256_bs8_it1000_do0.1/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp09_head4_emb256_bs8_it1000_do0.2",
#     "out_dir": "all_experiments/exp09_head4_emb256_bs8_it1000_do0.2",
#     "best_val_loss": 2.2390316247940065,
#     "best_ckpt_path": "all_experiments/exp09_head4_emb256_bs8_it1000_do0.2/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp10_head4_emb256_bs8_it2000_do0.1",
#     "out_dir": "all_experiments/exp10_head4_emb256_bs8_it2000_do0.1",
#     "best_val_loss": 1.904104471206665,
#     "best_ckpt_path": "all_experiments/exp10_head4_emb256_bs8_it2000_do0.1/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp11_head4_emb256_bs8_it2000_do0.2",
#     "out_dir": "all_experiments/exp11_head4_emb256_bs8_it2000_do0.2",
#     "best_val_loss": 2.0385487616062163,
#     "best_ckpt_path": "all_experiments/exp11_head4_emb256_bs8_it2000_do0.2/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp12_head4_emb256_bs16_it1000_do0.1",
#     "out_dir": "all_experiments/exp12_head4_emb256_bs16_it1000_do0.1",
#     "best_val_loss": 2.0118393659591676,
#     "best_ckpt_path": "all_experiments/exp12_head4_emb256_bs16_it1000_do0.1/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp13_head4_emb256_bs16_it1000_do0.2",
#     "out_dir": "all_experiments/exp13_head4_emb256_bs16_it1000_do0.2",
#     "best_val_loss": 2.095862603187561,
#     "best_ckpt_path": "all_experiments/exp13_head4_emb256_bs16_it1000_do0.2/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp14_head4_emb256_bs16_it2000_do0.1",
#     "out_dir": "all_experiments/exp14_head4_emb256_bs16_it2000_do0.1",
#     "best_val_loss": 1.750912642478943,
#     "best_ckpt_path": "all_experiments/exp14_head4_emb256_bs16_it2000_do0.1/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp15_head4_emb256_bs16_it2000_do0.2",
#     "out_dir": "all_experiments/exp15_head4_emb256_bs16_it2000_do0.2",
#     "best_val_loss": 1.8788793504238128,
#     "best_ckpt_path": "all_experiments/exp15_head4_emb256_bs16_it2000_do0.2/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp16_head8_emb128_bs8_it1000_do0.1",
#     "out_dir": "all_experiments/exp16_head8_emb128_bs8_it1000_do0.1",
#     "best_val_loss": 2.2994550347328184,
#     "best_ckpt_path": "all_experiments/exp16_head8_emb128_bs8_it1000_do0.1/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp17_head8_emb128_bs8_it1000_do0.2",
#     "out_dir": "all_experiments/exp17_head8_emb128_bs8_it1000_do0.2",
#     "best_val_loss": 2.3463687539100646,
#     "best_ckpt_path": "all_experiments/exp17_head8_emb128_bs8_it1000_do0.2/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp18_head8_emb128_bs8_it2000_do0.1",
#     "out_dir": "all_experiments/exp18_head8_emb128_bs8_it2000_do0.1",
#     "best_val_loss": 2.1461196541786194,
#     "best_ckpt_path": "all_experiments/exp18_head8_emb128_bs8_it2000_do0.1/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp19_head8_emb128_bs8_it2000_do0.2",
#     "out_dir": "all_experiments/exp19_head8_emb128_bs8_it2000_do0.2",
#     "best_val_loss": 2.2017704129219053,
#     "best_ckpt_path": "all_experiments/exp19_head8_emb128_bs8_it2000_do0.2/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp20_head8_emb128_bs16_it1000_do0.1",
#     "out_dir": "all_experiments/exp20_head8_emb128_bs16_it1000_do0.1",
#     "best_val_loss": 2.2152827501297,
#     "best_ckpt_path": "all_experiments/exp20_head8_emb128_bs16_it1000_do0.1/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp21_head8_emb128_bs16_it1000_do0.2",
#     "out_dir": "all_experiments/exp21_head8_emb128_bs16_it1000_do0.2",
#     "best_val_loss": 2.2707645654678346,
#     "best_ckpt_path": "all_experiments/exp21_head8_emb128_bs16_it1000_do0.2/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp22_head8_emb128_bs16_it2000_do0.1",
#     "out_dir": "all_experiments/exp22_head8_emb128_bs16_it2000_do0.1",
#     "best_val_loss": 1.978176575899124,
#     "best_ckpt_path": "all_experiments/exp22_head8_emb128_bs16_it2000_do0.1/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp23_head8_emb128_bs16_it2000_do0.2",
#     "out_dir": "all_experiments/exp23_head8_emb128_bs16_it2000_do0.2",
#     "best_val_loss": 2.061345952749252,
#     "best_ckpt_path": "all_experiments/exp23_head8_emb128_bs16_it2000_do0.2/ckpt_best.pt",
#     "num_params": 1206016
#   },
#   {
#     "run_id": "exp24_head8_emb256_bs8_it1000_do0.1",
#     "out_dir": "all_experiments/exp24_head8_emb256_bs8_it1000_do0.1",
#     "best_val_loss": 2.1913763523101806,
#     "best_ckpt_path": "all_experiments/exp24_head8_emb256_bs8_it1000_do0.1/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp25_head8_emb256_bs8_it1000_do0.2",
#     "out_dir": "all_experiments/exp25_head8_emb256_bs8_it1000_do0.2",
#     "best_val_loss": 2.23727787733078,
#     "best_ckpt_path": "all_experiments/exp25_head8_emb256_bs8_it1000_do0.2/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp26_head8_emb256_bs8_it2000_do0.1",
#     "out_dir": "all_experiments/exp26_head8_emb256_bs8_it2000_do0.1",
#     "best_val_loss": 1.9356029033660889,
#     "best_ckpt_path": "all_experiments/exp26_head8_emb256_bs8_it2000_do0.1/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp27_head8_emb256_bs8_it2000_do0.2",
#     "out_dir": "all_experiments/exp27_head8_emb256_bs8_it2000_do0.2",
#     "best_val_loss": 2.0273647129535677,
#     "best_ckpt_path": "all_experiments/exp27_head8_emb256_bs8_it2000_do0.2/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp28_head8_emb256_bs16_it1000_do0.1",
#     "out_dir": "all_experiments/exp28_head8_emb256_bs16_it1000_do0.1",
#     "best_val_loss": 2.0032860696315766,
#     "best_ckpt_path": "all_experiments/exp28_head8_emb256_bs16_it1000_do0.1/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp29_head8_emb256_bs16_it1000_do0.2",
#     "out_dir": "all_experiments/exp29_head8_emb256_bs16_it1000_do0.2",
#     "best_val_loss": 2.0937012672424316,
#     "best_ckpt_path": "all_experiments/exp29_head8_emb256_bs16_it1000_do0.2/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp30_head8_emb256_bs16_it2000_do0.1",
#     "out_dir": "all_experiments/exp30_head8_emb256_bs16_it2000_do0.1",
#     "best_val_loss": 1.7781240701675416,
#     "best_ckpt_path": "all_experiments/exp30_head8_emb256_bs16_it2000_do0.1/ckpt_best.pt",
#     "num_params": 4771328
#   },
#   {
#     "run_id": "exp31_head8_emb256_bs16_it2000_do0.2",
#     "out_dir": "all_experiments/exp31_head8_emb256_bs16_it2000_do0.2",
#     "best_val_loss": 1.8776876389980317,
#     "best_ckpt_path": "all_experiments/exp31_head8_emb256_bs16_it2000_do0.2/ckpt_best.pt",
#     "num_params": 4771328
#   }
# ]

# %%
import os
import torch
import pickle
import tiktoken
from contextlib import nullcontext
from model import GPT, GPTConfig

@torch.no_grad()
def generate_tokens(model, idx, max_new_tokens, temperature=1.0, top_k=None):
    # Same logic as model.generate(), inlined for clarity
    for _ in range(max_new_tokens):
        # crop context if it gets longer than block_size
        idx_cond = idx if idx.size(1) <= model.config.block_size else idx[:, -model.config.block_size:]

        # forward pass
        logits, _ = model(idx_cond)

        # get logits for last position
        logits = logits[:, -1, :] / temperature

        # optionally apply top-k filtering
        if top_k is not None:
            v, _ = torch.topk(logits, min(top_k, logits.size(-1)))
            logits[logits < v[:, [-1]]] = -float('inf')

        # convert logits to probabilities
        probs = torch.softmax(logits, dim=-1)

        # sample next token id
        idx_next = torch.multinomial(probs, num_samples=1)

        # append sampled token id to sequence
        idx = torch.cat((idx, idx_next), dim=1)

    return idx

def load_tokenizer_from_meta_or_gpt2(data_dir):
    """Return encode(str)->list[int], decode(list[int])->str."""
    meta_path = os.path.join(data_dir, "meta.pkl")
    if os.path.exists(meta_path):
        # character-level tokenizer from shakespeare_char
        with open(meta_path, "rb") as f:
            meta = pickle.load(f)
        stoi, itos = meta["stoi"], meta["itos"]
        encode = lambda s: [stoi[c] for c in s]
        decode = lambda l: "".join([itos[i] for i in l])
        return encode, decode
    else:
        # fallback to GPT-2 tokenizer
        enc = tiktoken.get_encoding("gpt2")
        encode = lambda s: enc.encode(s, allowed_special={"<|endoftext|>"})
        decode = lambda l: enc.decode(l)
        return encode, decode

def generate_from_checkpoint(
    exp_dir,
    data_dir,
    prompt,
    max_new_tokens=400,
    temperature=1.0,
    top_k=50,
    output_filename="sample_scene.txt",
    device=None,
):
    """
    Load ckpt_best.pt from exp_dir, rebuild the model, generate continuation
    from `prompt` (e.g. "\n"), and save it to {exp_dir}/{output_filename}.
    Returns the generated full text (prompt + completion).
    """

    ckpt_path = os.path.join(exp_dir, "ckpt_best.pt")
    if not os.path.exists(ckpt_path):
        raise FileNotFoundError(f"Could not find checkpoint at {ckpt_path}")

    # pick device
    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"
    device_type = "cuda" if "cuda" in device else "cpu"

    # load checkpoint
    ckpt = torch.load(ckpt_path, map_location=device)
    cfg = ckpt["config"]  # we saved model hyperparams here

    # infer vocab_size (char-level dataset or fallback)
    meta_path = os.path.join(data_dir, "meta.pkl")
    if os.path.exists(meta_path):
        with open(meta_path, "rb") as f:
            meta = pickle.load(f)
        vocab_size = meta["vocab_size"]
    else:
        vocab_size = 50304  # GPT-2 padded vocab_size used in nanoGPT

    # rebuild the model
    gptconf = GPTConfig(
        block_size=cfg["block_size"],
        vocab_size=vocab_size,
        n_layer=cfg["n_layer"],
        n_head=cfg["n_head"],
        n_embd=cfg["n_embd"],
        dropout=cfg["dropout"],
        bias=False,
    )
    model = GPT(gptconf)
    model.load_state_dict(ckpt["model_state_dict"])
    model.to(device)
    model.eval()

    # tokenizer
    encode, decode = load_tokenizer_from_meta_or_gpt2(data_dir)

    # turn prompt string -> tensor of token ids
    start_ids = encode(prompt)
    x = torch.tensor(start_ids, dtype=torch.long, device=device)[None, ...]

    # autocast for speed on GPU
    ctx = nullcontext() if device_type == "cpu" else torch.amp.autocast(
        device_type=device_type,
        dtype=(torch.bfloat16 if torch.cuda.is_bf16_supported() else torch.float16)
    )

    with ctx:
        y = generate_tokens(
            model,
            x,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            top_k=top_k,
        )

    # decode back to text
    full_text = decode(y[0].tolist())

    # save nice structured output for this model
    out_path = os.path.join(exp_dir, output_filename)
    with open(out_path, "w", encoding="utf-8") as f:
        f.write("PROMPT:\n")
        f.write(prompt)
        f.write("\n\nGENERATED:\n")
        f.write(full_text)
        f.write("\n")

    print(f"[OK] saved generation to {out_path}")
    return full_text

# %%
base_dir = "all_experiments"
data_dir = "data/shakespeare_char"  # same dataset you trained with

# This prompt style encourages "ANGELO:", "DUKE VINCENTIO:", etc.
scene_style_prompt = "\n\n"

for folder in sorted(os.listdir(base_dir)):
    exp_dir = os.path.join(base_dir, folder)
    if not os.path.isdir(exp_dir):
        continue

    print(f">>> Generating Shakespeare-style scene for {folder}")
    try:
        _ = generate_from_checkpoint(
            exp_dir=exp_dir,
            data_dir=data_dir,
            prompt=scene_style_prompt,
            max_new_tokens=400,   # give it room to create multiple speakers
            temperature=1.0,      # more creative / diverse speakers
            top_k=50,             # keeps language closer to 'Shakespeare play'
            output_filename="sample_scene.txt",
        )
    except Exception as e:
        print(f"[WARN] Skipping {folder} due to error: {e}")
# Out:
# >>> Generating Shakespeare-style scene for exp00_head4_emb128_bs8_it1000_do0.1
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp00_head4_emb128_bs8_it1000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp01_head4_emb128_bs8_it1000_do0.2
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp01_head4_emb128_bs8_it1000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp02_head4_emb128_bs8_it2000_do0.1
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp02_head4_emb128_bs8_it2000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp03_head4_emb128_bs8_it2000_do0.2
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp03_head4_emb128_bs8_it2000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp04_head4_emb128_bs16_it1000_do0.1
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp04_head4_emb128_bs16_it1000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp05_head4_emb128_bs16_it1000_do0.2
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp05_head4_emb128_bs16_it1000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp06_head4_emb128_bs16_it2000_do0.1
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp06_head4_emb128_bs16_it2000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp07_head4_emb128_bs16_it2000_do0.2
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp07_head4_emb128_bs16_it2000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp08_head4_emb256_bs8_it1000_do0.1
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp08_head4_emb256_bs8_it1000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp09_head4_emb256_bs8_it1000_do0.2
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp09_head4_emb256_bs8_it1000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp10_head4_emb256_bs8_it2000_do0.1
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp10_head4_emb256_bs8_it2000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp11_head4_emb256_bs8_it2000_do0.2
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp11_head4_emb256_bs8_it2000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp12_head4_emb256_bs16_it1000_do0.1
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp12_head4_emb256_bs16_it1000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp13_head4_emb256_bs16_it1000_do0.2
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp13_head4_emb256_bs16_it1000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp14_head4_emb256_bs16_it2000_do0.1
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp14_head4_emb256_bs16_it2000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp15_head4_emb256_bs16_it2000_do0.2
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp15_head4_emb256_bs16_it2000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp16_head8_emb128_bs8_it1000_do0.1
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp16_head8_emb128_bs8_it1000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp17_head8_emb128_bs8_it1000_do0.2
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp17_head8_emb128_bs8_it1000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp18_head8_emb128_bs8_it2000_do0.1
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp18_head8_emb128_bs8_it2000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp19_head8_emb128_bs8_it2000_do0.2
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp19_head8_emb128_bs8_it2000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp20_head8_emb128_bs16_it1000_do0.1
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp20_head8_emb128_bs16_it1000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp21_head8_emb128_bs16_it1000_do0.2
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp21_head8_emb128_bs16_it1000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp22_head8_emb128_bs16_it2000_do0.1
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp22_head8_emb128_bs16_it2000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp23_head8_emb128_bs16_it2000_do0.2
# number of parameters: 1.19M
# [OK] saved generation to all_experiments/exp23_head8_emb128_bs16_it2000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp24_head8_emb256_bs8_it1000_do0.1
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp24_head8_emb256_bs8_it1000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp25_head8_emb256_bs8_it1000_do0.2
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp25_head8_emb256_bs8_it1000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp26_head8_emb256_bs8_it2000_do0.1
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp26_head8_emb256_bs8_it2000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp27_head8_emb256_bs8_it2000_do0.2
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp27_head8_emb256_bs8_it2000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp28_head8_emb256_bs16_it1000_do0.1
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp28_head8_emb256_bs16_it1000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp29_head8_emb256_bs16_it1000_do0.2
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp29_head8_emb256_bs16_it1000_do0.2/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp30_head8_emb256_bs16_it2000_do0.1
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp30_head8_emb256_bs16_it2000_do0.1/sample_scene.txt
# >>> Generating Shakespeare-style scene for exp31_head8_emb256_bs16_it2000_do0.2
# number of parameters: 4.74M
# [OK] saved generation to all_experiments/exp31_head8_emb256_bs16_it2000_do0.2/sample_scene.txt

# %%
import os
import wandb
import matplotlib.pyplot as plt

ENTITY_NAME = "arunjung1991"         # <-- your wandb username or team
PROJECT_NAME = "nano-sweep"          # <-- the project you set in wandb_project

api = wandb.Api()

runs = api.runs(f"{ENTITY_NAME}/{PROJECT_NAME}")
print(f"Found {len(runs)} runs in {PROJECT_NAME}")
# Out:
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# Found 32 runs in nano-sweep

# %%
base_dir = "all_experiments"

for run in runs:
    run_id = run.name  # we set name=run_id in wandb.init(...)

    # Find matching local experiment folder
    exp_dir = os.path.join(base_dir, run_id)
    if not os.path.isdir(exp_dir):
        # if for some reason folder names don't match exactly, skip
        print(f"Skipping {run_id} (no dir {exp_dir})")
        continue

    print(f"Processing run {run_id} -> {exp_dir}")

    # download the full history (all logged steps)
    history = run.history(keys=[
        "iter",
        "loss/train_iter",
        "loss/train_eval",
        "loss/val",
        "loss/gap(train-val)",
        "lr",
        "gpu_mem_bytes",
        "num_params",
    ])

    # Convert to plain Python lists (Colab-friendly)
    iters         = history["iter"].tolist()
    train_now     = history["loss/train_iter"].tolist()
    train_eval    = history["loss/train_eval"].tolist()
    val_eval      = history["loss/val"].tolist()
    gap_eval      = history["loss/gap(train-val)"].tolist()
    lr_curve      = history["lr"].tolist()
    gpu_mem_curve = history["gpu_mem_bytes"].tolist()
    params_curve  = history["num_params"].tolist()

    # --- 1. Train vs Val loss plot ---
    plt.figure()
    plt.plot(iters, train_eval, label="train_eval_loss")
    plt.plot(iters, val_eval,   label="val_loss")
    plt.xlabel("iter")
    plt.ylabel("loss")
    plt.title(f"{run_id} - train vs val loss")
    plt.legend()
    plt.grid(True, alpha=0.3)
    loss_plot_path = os.path.join(exp_dir, "loss_curve.png")
    plt.savefig(loss_plot_path, dpi=200, bbox_inches="tight")
    plt.close()

    # --- 2. Gap plot (train_eval - val) ---
    plt.figure()
    plt.plot(iters, gap_eval, label="gap(train-val)")
    plt.xlabel("iter")
    plt.ylabel("loss gap")
    plt.title(f"{run_id} - train/val gap")
    plt.legend()
    plt.grid(True, alpha=0.3)
    gap_plot_path = os.path.join(exp_dir, "gap_curve.png")
    plt.savefig(gap_plot_path, dpi=200, bbox_inches="tight")
    plt.close()

    # --- 3. Learning rate schedule plot ---
    plt.figure()
    plt.plot(iters, lr_curve, label="lr")
    plt.xlabel("iter")
    plt.ylabel("learning rate")
    plt.title(f"{run_id} - LR schedule")
    plt.legend()
    plt.grid(True, alpha=0.3)
    lr_plot_path = os.path.join(exp_dir, "lr_curve.png")
    plt.savefig(lr_plot_path, dpi=200, bbox_inches="tight")
    plt.close()

    # --- 4. GPU memory usage plot (optional) ---
    if any(x is not None for x in gpu_mem_curve):
        plt.figure()
        plt.plot(iters, [m/(1024**2) if m is not None else None for m in gpu_mem_curve],
                 label="gpu_mem (MB)")
        plt.xlabel("iter")
        plt.ylabel("MB allocated")
        plt.title(f"{run_id} - GPU mem usage")
        plt.legend()
        plt.grid(True, alpha=0.3)
        mem_plot_path = os.path.join(exp_dir, "gpu_mem_curve.png")
        plt.savefig(mem_plot_path, dpi=200, bbox_inches="tight")
        plt.close()

    # --- 5. Save summary info as a metadata json (super helpful for comparison) ---
    summary_info = {
        "run_id": run_id,
        "num_params_final": params_curve[-1] if len(params_curve) else None,
        "final_train_eval_loss": train_eval[-1] if len(train_eval) else None,
        "final_val_loss": val_eval[-1] if len(val_eval) else None,
        "final_gap": gap_eval[-1] if len(gap_eval) else None,
        "min_val_loss": float(min(v for v in val_eval if v is not None)) if len(val_eval) else None,
        "sweep_config": run.config,  # contains n_head, n_embd, etc.
    }

    import json
    with open(os.path.join(exp_dir, "summary.json"), "w") as f:
        json.dump(summary_info, f, indent=2)

print("Done. Plots and summaries saved alongside each experiment.")
# Out:
# Processing run exp00_head4_emb128_bs8_it1000_do0.1 -> all_experiments/exp00_head4_emb128_bs8_it1000_do0.1
# Processing run exp01_head4_emb128_bs8_it1000_do0.2 -> all_experiments/exp01_head4_emb128_bs8_it1000_do0.2
# Processing run exp02_head4_emb128_bs8_it2000_do0.1 -> all_experiments/exp02_head4_emb128_bs8_it2000_do0.1
# Processing run exp03_head4_emb128_bs8_it2000_do0.2 -> all_experiments/exp03_head4_emb128_bs8_it2000_do0.2
# Processing run exp04_head4_emb128_bs16_it1000_do0.1 -> all_experiments/exp04_head4_emb128_bs16_it1000_do0.1
# Processing run exp05_head4_emb128_bs16_it1000_do0.2 -> all_experiments/exp05_head4_emb128_bs16_it1000_do0.2
# Processing run exp06_head4_emb128_bs16_it2000_do0.1 -> all_experiments/exp06_head4_emb128_bs16_it2000_do0.1
# Processing run exp07_head4_emb128_bs16_it2000_do0.2 -> all_experiments/exp07_head4_emb128_bs16_it2000_do0.2
# Processing run exp08_head4_emb256_bs8_it1000_do0.1 -> all_experiments/exp08_head4_emb256_bs8_it1000_do0.1
# Processing run exp09_head4_emb256_bs8_it1000_do0.2 -> all_experiments/exp09_head4_emb256_bs8_it1000_do0.2
# Processing run exp10_head4_emb256_bs8_it2000_do0.1 -> all_experiments/exp10_head4_emb256_bs8_it2000_do0.1
# Processing run exp11_head4_emb256_bs8_it2000_do0.2 -> all_experiments/exp11_head4_emb256_bs8_it2000_do0.2
# Processing run exp12_head4_emb256_bs16_it1000_do0.1 -> all_experiments/exp12_head4_emb256_bs16_it1000_do0.1
# Processing run exp13_head4_emb256_bs16_it1000_do0.2 -> all_experiments/exp13_head4_emb256_bs16_it1000_do0.2
# Processing run exp14_head4_emb256_bs16_it2000_do0.1 -> all_experiments/exp14_head4_emb256_bs16_it2000_do0.1
# Processing run exp15_head4_emb256_bs16_it2000_do0.2 -> all_experiments/exp15_head4_emb256_bs16_it2000_do0.2
# Processing run exp16_head8_emb128_bs8_it1000_do0.1 -> all_experiments/exp16_head8_emb128_bs8_it1000_do0.1
# Processing run exp17_head8_emb128_bs8_it1000_do0.2 -> all_experiments/exp17_head8_emb128_bs8_it1000_do0.2
# Processing run exp18_head8_emb128_bs8_it2000_do0.1 -> all_experiments/exp18_head8_emb128_bs8_it2000_do0.1
# Processing run exp19_head8_emb128_bs8_it2000_do0.2 -> all_experiments/exp19_head8_emb128_bs8_it2000_do0.2
# Processing run exp20_head8_emb128_bs16_it1000_do0.1 -> all_experiments/exp20_head8_emb128_bs16_it1000_do0.1
# Processing run exp21_head8_emb128_bs16_it1000_do0.2 -> all_experiments/exp21_head8_emb128_bs16_it1000_do0.2
# Processing run exp22_head8_emb128_bs16_it2000_do0.1 -> all_experiments/exp22_head8_emb128_bs16_it2000_do0.1
# Processing run exp23_head8_emb128_bs16_it2000_do0.2 -> all_experiments/exp23_head8_emb128_bs16_it2000_do0.2
# Processing run exp24_head8_emb256_bs8_it1000_do0.1 -> all_experiments/exp24_head8_emb256_bs8_it1000_do0.1
# Processing run exp25_head8_emb256_bs8_it1000_do0.2 -> all_experiments/exp25_head8_emb256_bs8_it1000_do0.2
# Processing run exp26_head8_emb256_bs8_it2000_do0.1 -> all_experiments/exp26_head8_emb256_bs8_it2000_do0.1
# Processing run exp27_head8_emb256_bs8_it2000_do0.2 -> all_experiments/exp27_head8_emb256_bs8_it2000_do0.2
# Processing run exp28_head8_emb256_bs16_it1000_do0.1 -> all_experiments/exp28_head8_emb256_bs16_it1000_do0.1
# Processing run exp29_head8_emb256_bs16_it1000_do0.2 -> all_experiments/exp29_head8_emb256_bs16_it1000_do0.2
# Processing run exp30_head8_emb256_bs16_it2000_do0.1 -> all_experiments/exp30_head8_emb256_bs16_it2000_do0.1
# Processing run exp31_head8_emb256_bs16_it2000_do0.2 -> all_experiments/exp31_head8_emb256_bs16_it2000_do0.2
# Done. Plots and summaries saved alongside each experiment.

# %%
import os

os.environ['GITHUB_TOKEN'] = '***************************'
os.environ['GITHUB_USER'] = '********************'

# now build the remote URL with the token embedded
repo_url = f"https://{os.environ['GITHUB_USER']}:{os.environ['GITHUB_TOKEN']}@github.com/{os.environ['GITHUB_USER']}/nanoGPT-Experiments.git"

# remove any old remotes and add the new one
# !git remote remove origin || true
# !git remote add origin $repo_url
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 1272, done.
# Counting objects: 100% (1272/1272), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (887/887), done.
# Writing objects: 100% (1272/1272), 11.78 MiB | 7.38 MiB/s, done.
# Total 1272 (delta 554), reused 684 (delta 380), pack-reused 0
# remote: Resolving deltas: 100% (554/554), done.
# To https://github.com/arunjung1991/nanoGPT-Experiments.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !pwd
# !ls -lh
# Out:
# /content/nanoGPT
# total 372K
# drwxr-xr-x 34 root root 4.0K Oct 28 04:51 all_experiments
# drwxr-xr-x  2 root root 4.0K Oct 28 04:50 assets
# -rw-r--r--  1 root root 4.8K Oct 28 04:50 bench.py
# drwxr-xr-x  2 root root 4.0K Oct 28 04:50 config
# -rw-r--r--  1 root root 1.8K Oct 28 04:50 configurator.py
# drwxr-xr-x  5 root root 4.0K Oct 28 04:50 data
# -rw-r--r--  1 root root 1.1K Oct 28 04:50 LICENSE
# -rw-r--r--  1 root root  16K Oct 28 04:50 model.py
# drwxr-xr-x  2 root root 4.0K Oct 28 04:50 __pycache__
# -rw-r--r--  1 root root  14K Oct 28 04:50 README.md
# -rw-r--r--  1 root root 3.9K Oct 28 04:50 sample.py
# -rw-r--r--  1 root root 263K Oct 28 04:50 scaling_laws.ipynb
# -rw-r--r--  1 root root  15K Oct 28 04:50 train.py
# -rw-r--r--  1 root root  15K Oct 28 04:50 transformer_sizing.ipynb
# drwxr-xr-x 34 root root 4.0K Oct 28 05:37 wandb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/nanoGPT_assignment.ipynb" /content/nanoGPT-Experiments/
# Out:
# cp: cannot create regular file '/content/nanoGPT-Experiments/': Not a directory
